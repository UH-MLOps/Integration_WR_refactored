# %%
import os

os.environ["MLFLOW_S3_ENDPOINT_URL"] = 'http://models-minio.vessel-ai.eu:9000'
os.environ["AWS_ACCESS_KEY_ID"] = 'minio'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'minio123'

# %%
import mlflow
import torch

from BinaryClassification import BinaryClassification

# %%
mlflow.set_tracking_uri('http://mlflow.vessel-ai.eu')
mlflow.set_experiment('WR_pretrained_model')
# Out:
# <Experiment: artifact_location='s3://mlflow/22', creation_time=None, experiment_id='22', last_update_time=None, lifecycle_stage='active', name='WR_pretrained_model', tags={}>

# %%
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
model_states = torch.load('pretrained_wr_v2.pt')['state_dict']
model = BinaryClassification()
model.load_state_dict(model_states)
# Out:
# <All keys matched successfully>

# %%
mlflow.pytorch.log_model(
    model,
    'wr_pretrained_model',
    registered_model_name='WR_pretrained_model'
)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/git/Integration_WR_refactored/.venv/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/git/Integration_WR_refactored/.venv/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/git/Integration_WR_refactored/.venv/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ...

# %%
mlflow.end_run()
